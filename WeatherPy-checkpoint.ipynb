# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\danie\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\danie\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
# api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=bengkulu
# Processing Record 2 | George Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=georgetown
# Processing Record 3 | Demba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=demba
# Processing Record 4 | Banjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=banjar
# Processing Record 5 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=tasiilaq
# Processing Record 6 | Eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=eureka
# Processing Record 7 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=vaini
# Processing Record 8 | Esmeraldas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=esmeraldas
# Processing Record 9 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=albany
# Processing Record 10 | Praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=praia
# Processing Record 11 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=port-gentil
# Processing Record 12 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=mar del plata
# Processing Record 13 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=vila velha
# Processing Record 14 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=atuona
# Processing Record 15 | Victor Harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=victor harbor
# Processing Record 16 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=tuatapere
# Processing Record 17 | Lokosovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=lokosovo
# Processing Record 18 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=lebu
# City not found. Skipping...
# Processing Record 19 | Iquique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=iquique
# Processing Record 20 | Londoko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=londoko
# Processing Record 21 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=bluff
# Processing Record 22 | Lakes Entrance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=lakes entrance
# Processing Record 23 | Marang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=marang
# Processing Record 24 | Atambua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=atambua
# Processing Record 25 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=busselton
# Processing Record 26 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=punta arenas
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 27 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ushuaia
# Processing Record 28 | Pemangkat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=pemangkat
# Processing Record 29 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=katsuura
# Processing Record 30 | Yiyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=yiyang
# Processing Record 31 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=pangnirtung
# Processing Record 32 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=upernavik
# Processing Record 33 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=east london
# Processing Record 34 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=hilo
# Processing Record 35 | Lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=lata
# City not found. Skipping...
# Processing Record 36 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=yar-sale
# Processing Record 37 | Abrau-Dyurso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=abrau-dyurso
# City not found. Skipping...
# Processing Record 38 | Sungairaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=sungairaya
# Processing Record 39 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=castro
# Processing Record 40 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=port elizabeth
# Processing Record 41 | Pec
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=pec
# Processing Record 42 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=saint george
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 | Khanbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=khandbari
# Processing Record 44 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kahului
# Processing Record 45 | Loa Janan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=loa janan
# Processing Record 46 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=vao
# Processing Record 47 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=yulara
# Processing Record 48 | Simao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=simao
# Processing Record 49 | Staryy Nadym
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=staryy nadym
# Processing Record 50 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=new norfolk
# Processing Record 51 | Tobermory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=tobermory
# Processing Record 52 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=mataura
# Processing Record 53 | Tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=tomatlan
# Processing Record 54 | Limbang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=limbang
# Processing Record 55 | Ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ugoofaaru
# Processing Record 56 | Soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=soyo
# Processing Record 57 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=port alfred
# Processing Record 58 | Bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=bud
# Processing Record 59 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=barrow
# Processing Record 60 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=hasaki
# Processing Record 61 | Semirom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=semirom
# Processing Record 62 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=mahebourg
# Processing Record 63 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kapaa
# Processing Record 64 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=pevek
# Processing Record 65 | Ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ambilobe
# Processing Record 66 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=hofn
# Processing Record 67 | Saint-Louis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=saint-louis
# Processing Record 68 | Prieska
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=prieska
# Processing Record 69 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=dikson
# Processing Record 70 | Undory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=undory
# Processing Record 71 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=qaanaaq
# Processing Record 72 | Marrakesh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=marrakesh
# Processing Record 73 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=faya
# Processing Record 74 | Cienfuegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=cienfuegos
# City not found. Skipping...
# Processing Record 75 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=pisco
# Processing Record 76 | Tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=tilichiki
# Processing Record 77 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=khatanga
# Processing Record 78 | Sai Buri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=sai buri
# City not found. Skipping...
# Processing Record 79 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=bambous virieux
# Processing Record 80 | Brasilia de Minas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=brasilia de minas
# Processing Record 81 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kaitangata
# Processing Record 82 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=hobart
# Processing Record 83 | Algiers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=algiers
# Processing Record 84 | Pasni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=pasni
# Processing Record 85 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=isangel
# City not found. Skipping...
# Processing Record 86 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=cockburn town
# City not found. Skipping...
# Processing Record 87 | Samarinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=samarinda
# Processing Record 88 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ponta do sol
# Processing Record 89 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ilulissat
# Processing Record 90 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=vila franca do campo
# Processing Record 91 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=salalah
# Processing Record 92 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=grindavik
# Processing Record 93 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=lompoc
# Processing Record 94 | Paka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=paka
# Processing Record 95 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=rikitea
# Processing Record 96 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=iqaluit
# Processing Record 97 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ponta delgada
# Processing Record 98 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=airai
# Processing Record 99 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=hithadhoo
# Processing Record 100 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ribeira grande
# City not found. Skipping...
# Processing Record 101 | Laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=laguna
# Processing Record 102 | Beni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=beni
# Processing Record 103 | Along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=along
# Processing Record 104 | Chui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=chuy
# Processing Record 105 | Kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kieta
# Processing Record 106 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=fortuna
# Processing Record 107 | Darhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=darhan
# Processing Record 108 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=klaksvik
# Processing Record 109 | Tungor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=tungor
# City not found. Skipping...
# Processing Record 110 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=yellowknife
# Processing Record 111 | Great Yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=great yarmouth
# Processing Record 112 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=codrington
# Processing Record 113 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=poum
# Processing Record 114 | Manoel Urbano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=manoel urbano
# City not found. Skipping...
# Processing Record 115 | Carballo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=carballo
# Processing Record 116 | Ukiah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ukiah
# Processing Record 117 | Mersing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=mersing
# Processing Record 118 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kodiak
# Processing Record 119 | Luwuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=luwuk
# Processing Record 120 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=hualmay
# Processing Record 121 | Sheregesh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=sheregesh
# Processing Record 122 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=norman wells
# Processing Record 123 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=puerto ayora
# Processing Record 124 | Bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=bambanglipuro
# Processing Record 125 | Borjomi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=borjomi
# Processing Record 126 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=saint-augustin
# Processing Record 127 | Severo-Kuril'sk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=severo-kurilsk
# Processing Record 128 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=zhigansk
# Processing Record 129 | Camrose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=camrose
# Processing Record 130 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=vardo
# City not found. Skipping...
# Processing Record 131 | Puerto Penasco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=puerto penasco
# Processing Record 132 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kavaratti
# Processing Record 133 | Bera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=bera
# Processing Record 134 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=talnakh
# Processing Record 135 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=cape town
# Processing Record 136 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=souillac
# Processing Record 137 | Dongobesh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=dongobesh
# Processing Record 138 | Kendari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kendari
# Processing Record 139 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ahipara
# Processing Record 140 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=nuuk
# Processing Record 141 | San Policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=san policarpo
# Processing Record 142 | Panguipulli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=panguipulli
# Processing Record 143 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=touros
# Processing Record 144 | Agia Galini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ayia galini
# Processing Record 145 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=tuktoyaktuk
# Processing Record 146 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=hobyo
# Processing Record 147 | Coolum Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=coolum beach
# Processing Record 148 | Hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=hirara
# Processing Record 149 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=srednekolymsk
# Processing Record 150 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=bredasdorp
# Processing Record 151 | Veraval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=veraval
# Processing Record 152 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=cherskiy
# City not found. Skipping...
# Processing Record 153 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=chokurdakh
# Processing Record 154 | Novonikolayevskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=novonikolayevskiy
# Processing Record 155 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=butaritari
# Processing Record 156 | Puerto Leguizamo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=puerto leguizamo
# Processing Record 157 | Karacabey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=karacabey
# Processing Record 158 | Pandamatenga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=pandamatenga
# Processing Record 159 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ancud
# Processing Record 160 | Siocon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=siocon
# Processing Record 161 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=avarua
# Processing Record 162 | Ust-Tsilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ust-tsilma
# Processing Record 163 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=tiksi
# Processing Record 164 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=luderitz
# Processing Record 165 | Bundaberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=bundaberg
# Processing Record 166 | Champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=champerico
# City not found. Skipping...
# Processing Record 167 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=bubaque
# Processing Record 168 | Normandin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=normandin
# Processing Record 169 | Sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=sambava
# Processing Record 170 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=esperance
# Processing Record 171 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=longyearbyen
# Processing Record 172 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=jamestown
# Processing Record 173 | Smithers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=smithers
# Processing Record 174 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=hermanus
# Processing Record 175 | Pacifica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=pacifica
# Processing Record 176 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kavieng
# Processing Record 177 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=leningradskiy
# Processing Record 178 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=nikolskoye
# City not found. Skipping...
# Processing Record 179 | Tigzirt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=tigzirt
# Processing Record 180 | Mulege
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=mulege
# Processing Record 181 | Ulaangom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ulaangom
# Processing Record 182 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=saint-philippe
# Processing Record 183 | Wakkanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=wakkanai
# Processing Record 184 | Bac Lieu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=bac lieu
# Processing Record 185 | Zaysan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=zaysan
# Processing Record 186 | Kiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kiama
# Processing Record 187 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=faanui
# Processing Record 188 | Brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=brae
# City not found. Skipping...
# Processing Record 189 | Guiren
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=guiren
# Processing Record 190 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=thompson
# Processing Record 191 | Chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=chicama
# Processing Record 192 | Bozeman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=bozeman
# Processing Record 193 | Susangerd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=susangerd
# Processing Record 194 | Provincia di Mantova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=mantua
# Processing Record 195 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=beringovskiy
# Processing Record 196 | Prescott
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=prescott
# Processing Record 197 | Carmelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=carmelo
# Processing Record 198 | Manado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=manado
# Processing Record 199 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=taoudenni
# Processing Record 200 | Canutama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=canutama
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 201 | Rudnaya Pristan'
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=rudnaya pristan
# Processing Record 202 | Sept-Iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=sept-iles
# Processing Record 203 | Sao Geraldo do Araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=sao geraldo do araguaia
# Processing Record 204 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=cabo san lucas
# City not found. Skipping...
# Processing Record 205 | Cesena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=cesena
# Processing Record 206 | Si Chiang Mai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=si chiang mai
# Processing Record 207 | Olivehurst
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=olivehurst
# Processing Record 208 | Hervey Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=hervey bay
# Processing Record 209 | Tskaltubo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=tskaltubo
# City not found. Skipping...
# Processing Record 210 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=sitka
# Processing Record 211 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=los llanos de aridane
# Processing Record 212 | Camacupa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=camacupa
# Processing Record 213 | Yanam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=yanam
# Processing Record 214 | Zuwarah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=zuwarah
# Processing Record 215 | Malakal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=malakal
# Processing Record 216 | Novyy Nekouz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=novyy nekouz
# Processing Record 217 | Hong Kong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=victoria
# City not found. Skipping...
# Processing Record 218 | Askiz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=askiz
# Processing Record 219 | Landeck
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=landeck
# Processing Record 220 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=lorengau
# Processing Record 221 | Kaabong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kaabong
# Processing Record 222 | Zheleznodorozhnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=zheleznodorozhnyy
# Processing Record 223 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=port hardy
# Processing Record 224 | Wajir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=wajir
# Processing Record 225 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=cidreira
# Processing Record 226 | Erzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=erzin
# Processing Record 227 | Kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kudahuvadhoo
# Processing Record 228 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=saldanha
# Processing Record 229 | Abu Kamal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=abu kamal
# Processing Record 230 | Albanel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=albanel
# Processing Record 231 | Kushima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kushima
# Processing Record 232 | Monster
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=monster
# City not found. Skipping...
# Processing Record 233 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=carnarvon
# Processing Record 234 | Eilat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=elat
# Processing Record 235 | Moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=moron
# Processing Record 236 | Dzhebariki-Khaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=dzhebariki-khaya
# Processing Record 237 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=margate
# Processing Record 238 | Rapid City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=rapid city
# Processing Record 239 | Manavalakurichi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=manavalakurichi
# Processing Record 240 | Khvoynaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=khvoynaya
# City not found. Skipping...
# Processing Record 241 | Fuerstenwalde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=furstenwalde
# Processing Record 242 | Eyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=eyl
# Processing Record 243 | Praia da Vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=praia da vitoria
# Processing Record 244 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=te anau
# Processing Record 245 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=husavik
# Processing Record 246 | Alice Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=alice town
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 247 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=clyde river
# Processing Record 248 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=saskylakh
# City not found. Skipping...
# Processing Record 249 | Lakatoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=lakatoro
# Processing Record 250 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=guerrero negro
# Processing Record 251 | Aasiaat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=aasiaat
# Processing Record 252 | Gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=gamba
# Processing Record 253 | Arvika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=arvika
# Processing Record 254 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=mount gambier
# Processing Record 255 | Ponerihouen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ponerihouen
# Processing Record 256 | Santa Luzia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=santa luzia
# Processing Record 257 | Coyhaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=coihaique
# Processing Record 258 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=nemuro
# City not found. Skipping...
# Processing Record 259 | Trairi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=trairi
# Processing Record 260 | Nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=nishihara
# Processing Record 261 | Kimbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kimbe
# Processing Record 262 | Sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=sola
# Processing Record 263 | Agadir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=agadir
# Processing Record 264 | Olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=olafsvik
# Processing Record 265 | Dudinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=dudinka
# Processing Record 266 | Chifeng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=chifeng
# Processing Record 267 | Opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=opuwo
# Processing Record 268 | Togur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=togur
# Processing Record 269 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=dingle
# Processing Record 270 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=torbay
# Processing Record 271 | Tucupita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=tucupita
# Processing Record 272 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=san patricio
# Processing Record 273 | Bardiyah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=bardiyah
# Processing Record 274 | Ossora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ossora
# Processing Record 275 | Zhengjiatun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=zhengjiatun
# Processing Record 276 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=nome
# Processing Record 277 | Roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=roald
# Processing Record 278 | Shihezi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=shihezi
# Processing Record 279 | Necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=necochea
# Processing Record 280 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=hambantota
# Processing Record 281 | Bereda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=bereda
# Processing Record 282 | La Ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=la ronge
# Processing Record 283 | Sistranda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=sistranda
# Processing Record 284 | Chu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=shu
# Processing Record 285 | Suamico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=suamico
# Processing Record 286 | Hibbing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=hibbing
# Processing Record 287 | Chibuto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=chibuto
# Processing Record 288 | Muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=muros
# City not found. Skipping...
# Processing Record 289 | Freeport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=freeport
# Processing Record 290 | Kortkeros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kortkeros
# Processing Record 291 | Sandakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=sandakan
# Processing Record 292 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=hamilton
# Processing Record 293 | Diego de Almagro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=diego de almagro
# Processing Record 294 | Almaznyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=almaznyy
# Processing Record 295 | Atbasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=atbasar
# Processing Record 296 | Borba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=borba
# Processing Record 297 | Viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=viedma
# Processing Record 298 | Turka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=turka
# City not found. Skipping...
# Processing Record 299 | Sao Jose da Coroa Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=sao jose da coroa grande
# Processing Record 300 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=constitucion
# Processing Record 301 | Boulder
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=boulder
# Processing Record 302 | Karema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=karema
# Processing Record 303 | Terrace
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=terrace
# Processing Record 304 | Quito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=quito
# Processing Record 305 | Port Charlotte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=port charlotte
# Processing Record 306 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=fairbanks
# Processing Record 307 | Salzgitter
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=salzgitter
# Processing Record 308 | Mabaruma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=mabaruma
# Processing Record 309 | College
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=college
# Processing Record 310 | San Ignacio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=san ignacio
# Processing Record 311 | Heihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=heihe
# Processing Record 312 | Koungou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=koungou
# Processing Record 313 | Kichmengskiy Gorodok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kichmengskiy gorodok
# City not found. Skipping...
# Processing Record 314 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=aklavik
# Processing Record 315 | Luba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=luba
# Processing Record 316 | Pontes e Lacerda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=pontes e lacerda
# Processing Record 317 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=port lincoln
# Processing Record 318 | Grand Bank
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=grand bank
# Processing Record 319 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=naze
# Processing Record 320 | Ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ayan
# Processing Record 321 | Niono
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=niono
# Processing Record 322 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=dunedin
# Processing Record 323 | Mana
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=avera
# Processing Record 457 | Daru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=daru
# Processing Record 458 | Campbellton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=campbellton
# Processing Record 459 | Timmins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=timmins
# City not found. Skipping...
# Processing Record 460 | Makakilo City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=makakilo city
# Processing Record 461 | Gusau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=gusau
# Processing Record 462 | Araguaina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=araguaina
# City not found. Skipping...
# Processing Record 463 | Murgab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=murgab
# Processing Record 464 | Melfort
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=melfort
# Processing Record 465 | Verkhnyaya Inta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=verkhnyaya inta
# Processing Record 466 | Kurkino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kurkino
# Processing Record 467 | Presidencia Roque Saenz Pena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=presidencia roque saenz pena
# Processing Record 468 | Oodweyne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=odweyne
# Processing Record 469 | Port Hueneme
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=port hueneme
# Processing Record 470 | Sena Madureira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=sena madureira
# Processing Record 471 | Auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=auki
# Processing Record 472 | Laurel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=laurel
# Processing Record 473 | Washougal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=washougal
# Processing Record 474 | Yamada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=yamada
# Processing Record 475 | Chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=chapais
# Processing Record 476 | Buin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=buin
# Processing Record 477 | Yangi Marg`ilon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=komsomolskiy
# Processing Record 478 | Fare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=fare
# Processing Record 479 | Aracati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=aracati
# Processing Record 480 | Cozumel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=cozumel
# Processing Record 481 | Wahiawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=wahiawa
# Processing Record 482 | Tamiahua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=tamiahua
# City not found. Skipping...
# Processing Record 483 | Banes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=banes
# Processing Record 484 | Khash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=khash
# Processing Record 485 | Batagay-Alyta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=batagay-alyta
# Processing Record 486 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=pacific grove
# City not found. Skipping...
# Processing Record 487 | Vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=vila
# Processing Record 488 | Polunochnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=polunochnoye
# Processing Record 489 | Conde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=conde
# Processing Record 490 | Jardim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=jardim
# Processing Record 491 | Xichang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=xichang
# Processing Record 492 | Yablonovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=yablonovo
# Processing Record 493 | Keroka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=keroka
# Processing Record 494 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=haines junction
# Processing Record 495 | Ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ketchikan
# Processing Record 496 | San Jose de Ocoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=san jose de ocoa
# Processing Record 497 | Las Vegas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=las vegas
# Processing Record 498 | Beipiao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=beipiao
# Processing Record 499 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=sioux lookout
# Processing Record 500 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=bathsheba
# Processing Record 501 | Usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=usinsk
# Processing Record 502 | Homer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=homer
# Processing Record 503 | Ayagoz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ayagoz
# Processing Record 504 | Ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ballina
# Processing Record 505 | Koster
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=koster
# Processing Record 506 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=mehamn
# Processing Record 507 | Alakurtti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=alakurtti
# Processing Record 508 | Gao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=gao
# Processing Record 509 | North Tonawanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=north tonawanda
# Processing Record 510 | Adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=adrar
# Processing Record 511 | Joao Pinheiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=joao pinheiro
# City not found. Skipping...
# Processing Record 512 | Loralai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=loralai
# Processing Record 513 | Skibbereen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=skibbereen
# Processing Record 514 | Belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=belmonte
# Processing Record 515 | Berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=berdigestyakh
# Processing Record 516 | Laas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=lasa
# Processing Record 517 | Aldan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=aldan
# Processing Record 518 | Jhudo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=jhudo
# Processing Record 519 | Syamzha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=syamzha
# Processing Record 520 | Bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=bilma
# Processing Record 521 | Anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=anadyr
# Processing Record 522 | Nyrob
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=nyrob
# Processing Record 523 | Casian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=casian
# Processing Record 524 | Araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=araouane
# Processing Record 525 | Trinidad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=trinidad
# Processing Record 526 | Sam Roi Yot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=sam roi yot
# Processing Record 527 | Paita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=paita
# Processing Record 528 | Kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kiunga
# Processing Record 529 | Salamanca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=salamanca
# Processing Record 530 | Satun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=satun
# Processing Record 531 | Antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=antofagasta
# Processing Record 532 | Gilgit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=gilgit
# Processing Record 533 | Wau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=wau
# Processing Record 534 | Alugan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=alugan
# Processing Record 535 | Noyabrsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=noyabrsk
# Processing Record 536 | Marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=marzuq
# Processing Record 537 | Fort Nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=fort nelson
# Processing Record 538 | Derbent
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=derbent
# Processing Record 539 | Pandan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=pandan
# Processing Record 540 | Emirdag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=emirdag
# Processing Record 541 | Yenagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=yenagoa
# Processing Record 542 | Raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=raudeberg
# Processing Record 543 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=ostrovnoy
# Processing Record 544 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=vanimo
# Processing Record 545 | Bara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=bara
# Processing Record 546 | Buncrana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=buncrana
# City not found. Skipping...
# Processing Record 547 | Port Macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=port macquarie
# Processing Record 548 | Phek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=phek
# Processing Record 549 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=mount isa
# Processing Record 550 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=alice springs
# Processing Record 551 | Cerrito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=cerrito
# City not found. Skipping...
# Processing Record 552 | Chengzhong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=yingcheng
# Processing Record 553 | Kirkwood
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kirkwood
# Processing Record 554 | Tambun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=tambun
# Processing Record 555 | Butembo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=butembo
# Processing Record 556 | Maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=maceio
# Processing Record 557 | Kidal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kidal
# Processing Record 558 | Kongoussi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=kongoussi
# Processing Record 559 | Nacala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=nacala
# Processing Record 560 | Karpogory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=karpogory
# Processing Record 561 | Artvin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=artvin
# Processing Record 562 | Baruun-Urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=baruun-urt
# Processing Record 563 | Pringsewu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=pringsewu
# Processing Record 564 | Mantenopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b36184641483dc7edf847dd4aa11f2f&q=mantenopolis

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_data.count()
# Out:
# City          564
# Cloudiness    564
# Country       564
# Date          564
# Humidity      564
# Lat           564
# Lng           564
# Max Temp      564
# Wind Speed    564
# dtype: int64

# %%
# Save data frame to CSV
weather_data.to_csv("../output_data/weather_data.csv")

# Display data frame head 
weather_data.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Bengkulu         100      ID  1580354402        47  -3.80  102.27
# 1  George Town          20      MY  1580354131        66   5.41  100.34
# 2        Demba         100      CD  1580354404        98  -5.51   22.27
# 3       Banjar          75      ID  1580354405        84  -8.19  114.97
# 4     Tasiilaq          91      GL  1580354406        68  65.61  -37.64
#
#    Max Temp  Wind Speed
# 0     84.54        5.46
# 1     86.00        6.93
# 2     69.37        2.62
# 3     87.80       11.41
# 4     28.40       31.09

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Temp_vs_Lat.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#build a scatter plot 5for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

#incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

#save
plt.savefig("../output_data/Humidity_vs_Lat.png")

#show
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Cloud_vs_Lat.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Wind_vs_Lat.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
nothern = weather_data.loc[weather_data["Lat"] >= 0.0]
nothern.reset_index(inplace=True)

southern = weather_data.loc[weather_data["Lat"] < 0.0]
southern.reset_index(inplace=True)

def plotLinearRegression(xdata,ydata,xlbl,ylbl,lblpos,ifig):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(xdata, ydata)
    print(f"The r-squared is: {rvalue}")
    regress_values = xdata * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(xdata,ydata)
    plt.plot(xdata,regress_values,"r-")
    plt.annotate(line_eq,lblpos,fontsize=15,color="red")
    plt.xlabel(xlbl)
    plt.ylabel(ylbl)
    plt.savefig("../output_data/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Max Temp"
lblpos = (0,25)
plotLinearRegression(nothern[xlbl],nothern[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: -0.8743659324370502

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Max Temp"
lblpos = (-55,90)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,6)
# Out:
# The r-squared is: 0.35577252703176604

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Humidity"
lblpos = (45,10)
plotLinearRegression(nothern[xlbl],nothern[ylbl],xlbl,ylbl,lblpos,7)
# Out:
# The r-squared is: 0.37738579385007753

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Humidity"
lblpos = (-55,15)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,8)
# Out:
# The r-squared is: 0.32397220248158365

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Cloudiness"
lblpos = (20,40)
plotLinearRegression(nothern[xlbl],nothern[ylbl],xlbl,ylbl,lblpos,9)
# Out:
# The r-squared is: 0.21708876640687214

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Cloudiness"
lblpos = (-55,50)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,10)
# Out:
# The r-squared is: 0.3302817878759031

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Wind Speed"
lblpos = (0,30)
plotLinearRegression(nothern[xlbl],nothern[ylbl],xlbl,ylbl,lblpos,11)
# Out:
# The r-squared is: 0.06379983322261645

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Wind Speed"
lblpos = (-25,33)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,12)
# Out:
# The r-squared is: -0.46750578691436795

# %%
### Observations

#1. Looking at the correlation, higher the latitude, the lower the temperature goes. 
#2. Humidity and cloudiness seem to have no correlations with latitude. 
#3. Observing the Wind speed versus latitude charts, there is little correlations between the two.
